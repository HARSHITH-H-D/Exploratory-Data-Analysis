# %%
import pandas as pd
import numpy as np
# Generate random data
np.random.seed(42)
num_points = 100
latitude = np.random.uniform(8.4, 37.6, num_points)
longitude = np.random.uniform(68.7, 97.25, num_points)
value = np.random.randint(1, 100, num_points)
# Create a DataFrame
df = pd.DataFrame({'Latitude': latitude, 'Longitude': longitude, 'Value': value})
# Save the DataFrame to a CSV file
df.to_csv('map_data.csv', index=False)

# %%
import folium
# Load the generated CSV file
df = pd.read_csv('map_data.csv')
# Create a base map
base_map	=	folium.Map(location=[df['Latitude'].mean(),	df['Longitude'].mean()], zoom_start=10)
# Add data points to the map
for index, row in df.iterrows():
  popup_text = f"Value: {row['Value']}"
  folium.Marker([row['Latitude'],   row['Longitude']],popup=popup_text).add_to(base_map)
# Save the map as an HTML file
base_map.save('interactive_map.html')

# %%
import pandas as pd
import folium # Load the data
df = pd.read_csv('map_data.csv')
# Display basic statistics
print("Basic Statistics:")
print(df.describe())
# Create a base map
base_map	=	folium.Map(location=[df['Latitude'].mean(),	df['Longitude'].mean()], zoom_start=10)
# Add data points to the map
for index, row in df.iterrows():
  popup_text = f"Value: {row['Value']}"
  folium.Marker([row['Latitude'],   row['Longitude']],   popup=popup_text).add_to(base_map)
# Display the map
base_map
# Out:
# Basic Statistics:
#          Latitude   Longitude       Value
# count  100.000000  100.000000  100.000000
# mean    22.129278   82.913096   50.670000
# std      8.686691    8.368326   28.640247
# min      8.561246   68.898483    2.000000
# 25%     14.041462   75.609229   27.000000
# 50%     21.952960   83.135590   47.500000
# 75%     29.721931   90.574542   72.750000
# max     37.217099   96.840320   99.000000
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc7a8428dc67b2de63bfecbeb32a3f25 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc7a8428dc67b2de63bfecbeb32a3f25&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc7a8428dc67b2de63bfecbeb32a3f25 = L.map(
#                 &quot;map_fc7a8428dc67b2de63bfecbeb32a3f25&quot;,
#                 {
#                     center: [22.12927770664372, 82.91309569607593],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61af87032d6fa1b62eb8647be727854d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_61af87032d6fa1b62eb8647be727854d.addTo(map_fc7a8428dc67b2de63bfecbeb32a3f25);
#
#
#             var marker_9b9446033c5008e50968636041ea4a76 = L.marker(
#                 [19.33657147034299, 69.59730325135627],
#                 {}
#             ).addTo(map_fc7a8428dc67b2de63bfecbeb32a3f25);
#
#
#         var popup_95f067978cc1cba2e8828877e2462fe9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_97eecad39eb47461245fdae53a1fe87c = $(`&lt;div id=&quot;html_97eecad39eb47461245fdae53a1fe87c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Value: 24.0&lt;/div&gt;`)[0];
#                 popup_95f067978cc1cba2e8828877e2462fe9.setContent(html_97eecad39eb47461245fdae53a1fe87c);
#
#
#
#         marker_9b9446033c5008e50968636041ea4a76.bindPopup(popup_95f067978cc1cba2e8828877e2462fe9)
#         ;
#
#
#
#
#             var marker_582bb511ead6d6f2a59a8f6350354471 = L.marker(
#                 [36.16085774716956, 86.86951724158092],
#                 {}
#             ).addTo(map_fc7a8428dc67b2de63bfecbeb32a3f25);
#
#
#         var popup_b4453c55f8654f7c83daf2c13db4aad5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_12e80bc11c294e6e6fa3d458855cdf34 = $(`&lt;div id=&quot;html_12e80bc11c294e6e6fa3d458855cdf34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Value: 75.0&lt;/div&gt;`)[0];
#                 popup_b4453c55f8654f7c83daf2c13db4aad5.setContent(html_12e80bc11c294e6e6fa3d458855cdf34);
#
#
#
#         marker_582bb511ead6d6f2a59a8f6350354471.bindPopup(popup_b4453c55f8654f7c83daf2c13db4aad5)
#         ;
#
#
#
#
#             var marker_c275ea528cf54387561a84eb82b59bdf = L.marker(
#                 [29.774223100893032, 77.67486325972914],
#                 {}
#             ).addTo(map_fc7a8428dc67b2de63bfecbeb32a3f25);
#
#
#         var popup_5ab937aeba7ff5036b0fa205b15f099b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_41ae642300eae84a941133f642261f72 = $(`&lt;div id=&quot;html_41ae642300eae84a941133f642261f72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Value: 72.0&lt;/div&gt;`)[0];
#                 popup_5ab937aeba7ff5036b0fa205b15f099b.setContent(html_41ae642300eae84a941133f642261f72);
#
#
#
#         marker_c275ea528cf54387561a84eb82b59bdf.bindPopup(popup_5ab937aeba7ff5036b0fa205b15f099b)
#         ;
#
#
#
#
#             var marker_16d346fbcb9e043422866b49c807ffef = L.marker(
#                 [25.88082773855347, 83.21969323275226],
#                 {}
#             ).addTo(map_fc7a8428dc67b2de63bfecbeb32a3f25);
#
#
#         var popup_95d6f7f256a7346b84814c4e282a647c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a8cbb447784a56bc21852d6ec47f3d05 = $(`&lt;div id=&quot;html_a8cbb447784a56bc21852d6ec47f3d05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Value: 36.0&lt;/div&gt;`)[0];
#                 popup_95d6f7f256a7346b84814c4e282a647c.setContent(html_a8cbb447784a56bc21852d6ec47f3d05);
#
#
#
#         marker_16d346fbcb9e043422866b49c807ffef.bindPopup(popup_95d6f7f256a7346b84814c4e282a647c)
#         ;
#
#
#
#
#             var marker_10893c3aa465f70f4e46db7ccc67388c = L.marker(
#                 [12.955744300919148, 94.61102283058996],
#                 {}
#             ).addTo(map_fc7a8428dc67b2de63bfecbeb32a3f25);
#
#
#         var popup_298dda5d69c0bee526f452d9bdca75d5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0b6d8d3ddd8878bdae174ebed5e2e681 = $(`&lt;div id=&quot;html_0b6d8d3ddd8878bdae174ebed5e2e681&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Value: 38.0&lt;/div&gt;`)[0];
#                 popup_298dda5d69c0bee526f452d9bdca75d5.setContent(html_0b6d8d3ddd8878bdae174ebed5e2e681);
#
#
#
#         marker_10893c3aa465f70f4e46db7ccc67388c.bindPopup(popup_298dda5d69c0bee526f452d9bdca75d5)
#         ;
#
#
#
#
#             var marker_37dcdd09798b1f0ef8672ce9bd64a361 = L.marker(
#                 [12.955039993
